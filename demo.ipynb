# %% [markdown]
# <a href="https://colab.research.google.com/github/kadomoto/picture-to-gds/blob/master/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gradio as gr

import picToGDS

def main(fileName, sizeOfTheCell, layerNum, isDither, scale):
    picToGDS.main(fileName, sizeOfTheCell, layerNum, isDither, scale)
    return "image.bmp", "image.gds"

demo = gr.Interface(
    fn=main,
    inputs=[gr.Image(type="filepath"), "number", "number", "checkbox", "number"],
    outputs=[gr.Image(type="filepath"), "file"]
)
demo.launch(share=True)
